# %% [markdown]
# # LOADING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
from PIL import Image

# %% [markdown]
# # LOADING DATASET

# %%
df = pd.read_csv("CommentsMay2017.csv")
# Out:
# C:\Users\SUVAM DAS\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    approveDate                                        commentBody  commentID  \
# 0   1494713997  Thank you for this piece. Intersected with my ...   22481999
# 1   1494207396  Between 2010 up until June of last year I visi...   22404509
# 2   1494207395  "Yet Beijing’s streets, walls, temples, garden...   22403818
# 3   1494180991  this is a romantic view of the city, one that ...   22401188
# 4   1494180991  I work with Chinese in film and technology. Th...   22398900
#
#    commentSequence commentTitle commentType  createDate  depth  \
# 0         22481999        <br/>     comment  1494639109      1
# 1         22404509        <br/>     comment  1494201387      1
# 2         22403818        <br/>     comment  1494193340      1
# 3         22401188        <br/>     comment  1494172465      1
# 4         22398900        <br/>     comment  1494158499      1
#
#    editorsSelection  parentID  ...            userLocation userTitle userURL  \
# 0             False         0  ...     Des Moines, IA, USA       NaN     NaN
# 1             False         0  ...  east lansing, michigan       NaN     NaN
# 2             False         0  ...                Auckland       NaN     NaN
# 3             False         0  ...              New Jersey       NaN     NaN
# 4             False         0  ...                     NYC       NaN     NaN
#
#    inReplyTo                 articleID  sectionName  newDesk  \
# 0          0  5906b3197c459f24986dd003      Unknown   Travel
# 1          0  5906b3197c459f24986dd003      Unknown   Travel
# 2          0  5906b3197c459f24986dd003      Unknown   Travel
# 3          0  5906b3197c459f24986dd003      Unknown   Travel
# 4          0  5906b3197c459f24986dd003      Unknown   Travel
#
#    articleWordCount printPage  typeOfMaterial
# 0              2412         1            News
# 1              2412         1            News
# 2              2412         1            News
# 3              2412         1            News
# 4              2412         1            News
#
# [5 rows x 34 columns]

# %%
df = df[['commentBody']]
df.head()
# Out:
#                                          commentBody
# 0  Thank you for this piece. Intersected with my ...
# 1  Between 2010 up until June of last year I visi...
# 2  "Yet Beijing’s streets, walls, temples, garden...
# 3  this is a romantic view of the city, one that ...
# 4  I work with Chinese in film and technology. Th...

# %% [markdown]
# # CREATING SIMPLE WORD-CLOUD

# %%
def Tokenizer(text):
    """Simple Tokenizer function which also converts complete corpus into lowercase. Input the text"""
    full_string = ''
    for sentence in text:
        sent = str(sentence)
        token = sent.split()
        for i in range(len(token)):
            token[i] = token[i].lower()
        full_string += " ".join(token)
    return full_string

# %%
full_string = Tokenizer(df['commentBody'])

# %%
full_string[0:50]
# Out:
# 'thank you for this piece. intersected with my own '

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(width = 500,height=500,background_color='black',stopwords=stopwords,min_font_size=10).generate(full_string)

# %%
#Plotting the WordCloud
plt.figure(figsize=(7,7))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
